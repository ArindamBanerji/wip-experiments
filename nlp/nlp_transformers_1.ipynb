# %% [markdown]
# <a href="https://colab.research.google.com/github/ArindamBanerji/wip_expts/blob/wip_main/nlp_transformers_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Uncomment and run this cell if you're on Colab or Kaggle - should not be required....
# !git clone https://github.com/nlp-with-transformers/notebooks.git
# %cd notebooks
# Out:
# Cloning into 'notebooks'...
# remote: Enumerating objects: 502, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 502 (delta 98), reused 93 (delta 86), pack-reused 378
# Receiving objects: 100% (502/502), 29.34 MiB | 17.40 MiB/s, done.
# Resolving deltas: 100% (234/234), done.

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd notebooks
# %pwd
# Out:
# /content/notebooks
# '/content/notebooks'

# %%
from install import *
install_requirements()
# Out:
# ⏳ Installing base requirements ...
# ✅ Base requirements installed!
# ⏳ Installing Git LFS ...
# ✅ Git LFS installed!

# %%
from utils import *
setup_chapter()
# Out:
# Using transformers v4.11.3
# Using datasets v1.16.1

# %%
text = """Dear Amazon, last week I ordered an Optimus Prime action figure \
from your online store in Germany. Unfortunately, when I opened the package, \
I discovered to my horror that I had been sent an action figure of Megatron \
instead! As a lifelong enemy of the Decepticons, I hope you can understand my \
dilemma. To resolve the issue, I demand an exchange of Megatron for the \
Optimus Prime figure I ordered. Enclosed are copies of my records concerning \
this purchase. I expect to hear from you soon. Sincerely, Bumblebee."""

# %% [markdown]
# # Text Classification

# %%
#hide_output
from transformers import pipeline

classifier = pipeline("text-classification")
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
import pandas as pd

outputs = classifier(text)
pd.DataFrame(outputs)
# Out:
#       label     score
# 0  NEGATIVE  0.901546

# %% [markdown]
# ## Named Entity Recognition

# %%
ner_tagger = pipeline("ner", aggregation_strategy="simple")
outputs = ner_tagger(text)
pd.DataFrame(outputs)
# Out:
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
#   entity_group     score           word  start  end
# 0          ORG  0.879011         Amazon      5   11
# 1         MISC  0.990859  Optimus Prime     36   49
# 2          LOC  0.999755        Germany     90   97
# 3         MISC  0.556571           Mega    208  212
# 4          PER  0.590256         ##tron    212  216
# 5          ORG  0.669692         Decept    253  259
# 6         MISC  0.498349        ##icons    259  264
# 7         MISC  0.775362       Megatron    350  358
# 8         MISC  0.987854  Optimus Prime    367  380
# 9          PER  0.812096      Bumblebee    502  511

# %%
# %ls ./content/notebooks/
# Out:
# 01_introduction.ipynb               environment.yml
# 02_classification.ipynb             images/
# 03_transformer-anatomy.ipynb        install.py
# 04_multilingual-ner.ipynb           LICENSE
# 05_text-generation.ipynb            plotting.mplstyle
# 06_summarization.ipynb              __pycache__/
# 07_question-answering.ipynb         README.md
# 07_question_answering_v2.ipynb      requirements-chapter7.txt
# 08_model-compression.ipynb          requirements-chapter7-v2.txt
# 09_few-to-no-labels.ipynb           requirements.txt
# 10_transformers-from-scratch.ipynb  SageMaker/
# 11_future-directions.ipynb          scripts/
# data/                               settings.ini
# environment-chapter7.yml            utils.py

# %%
import os
def find_files(filename, search_path):
   result = []

# Wlaking top-down from the root
   for root, dir, files in os.walk(search_path):
      if filename in files:
         result.append(os.path.join(root, filename))
   return result

print(find_files("01_introduction.ipynb","."))
# Out:
# ['./content/notebooks/01_introduction.ipynb',
# './content/notebooks/SageMaker/01_introduction.ipynb']
